# %%
import numpy as np
import torch
from sine_utils import run_sine_segmentation
import plotly.graph_objects as go

raw_data = torch.load('/home/user/codes/POWERODE/ode/LatentSegmentedODE-main/LatentSegmentedODE-main/SineWave/Data/Test/sine_test_100_7_0.025_3')
data = raw_data['data']

print(data)

# for i in range(len(data)):
#     lst = data[i]
#     d = np.squeeze(lst[1])
#     t = np.squeeze(lst[0])

#     fig = go.Figure()
#     fig.add_trace(go.Scatter( x = d , y = t ,mode='lines', name='lines')) 
#     fig.show()
# Out:
# [(array([[[ 8.07415937],
#         [ 7.73216259],
#         [ 7.25318082],
#         [ 5.51461554],
#         [ 4.75981605],
#         [ 4.730285  ],
#         [ 3.55950273],
#         [ 3.18160443],
#         [ 3.18042904],
#         [ 2.50466014],
#         [ 0.19862185],
#         [-1.23503322],
#         [-4.30381738],
#         [-4.76713103],
#         [-5.02683118],
#         [-5.8899061 ],
#         [-8.74346835],
#         [-9.0421504 ],
#         [-9.18874042],
#         [-9.15287976],
#         [-9.14129227],
#         [-8.80988123],
#         [-8.42773012],
#         [-7.9131076 ],
#         [-7.6350569 ],
#         [-5.87188249],
#         [-5.12059617],
#         [-3.27190643],
#         [-2.69087279],
#         [-0.75934831],
#         [-0.65550969],
#         [ 2.66909232],
#         [ 2.81910322],
#         [ 3.08943003],
#         [ 3.12294897],
#         [ 4.88303644],
#         [ 4.93186445],
#         [ 5.38476653],
#         [ 6.49794441],
# ...

# %%
import numpy as np
import torch
from sine_utils import run_sine_segmentation
import plotly.graph_objects as go

raw_data = torch.load('/home/user/codes/POWERODE/ode/LatentSegmentedODE-main/LatentSegmentedODE-main/SineWave/Data/Train/sine_train_10000_1000_0.5_0.02')

data = raw_data['generator'].train_data
t = raw_data['generator'].train_time

print(t)

ind = 4000
for i in range(len(data)):
    if i>ind and i<(ind+20):
        print()
        d = data[i]
        fig = go.Figure()
        fig.add_trace(go.Scatter( x = t , y = d ,mode='lines', name='lines')) 
        fig.show()
# Out:
# [0.00058667 0.00081993 0.00171898 0.00209448 0.00311528 0.00322927
#  0.00483963 0.00550084 0.00637316 0.00664424 0.00942412 0.00959916
#  0.01026848 0.01035613 0.01043751 0.01058014 0.01107857 0.01119549
#  0.01152688 0.01273254 0.01290567 0.01294167 0.01308485 0.01365054
#  0.01464878 0.01470722 0.01502833 0.01572607 0.01589465 0.01599352
#  0.01604122 0.01611712 0.01616386 0.01729961 0.01813102 0.01855366
#  0.01865219 0.02064092 0.02275708 0.02290999 0.02296649 0.02313711
#  0.02348545 0.02380069 0.02383433 0.02430121 0.0254995  0.02581219
#  0.02758088 0.02789122 0.02903516 0.02947935 0.03011933 0.03052057
#  0.0340084  0.03465575 0.03527426 0.03567773 0.03611191 0.03621478
#  0.03681126 0.0376262  0.03812634 0.03828565 0.03923837 0.03947764
#  0.04082559 0.04160285 0.04284996 0.04306989 0.04425372 0.04539095
#  0.0453966  0.04540038 0.04684171 0.04697294 0.04732884 0.04733533
#  0.0474061  0.0483793  0.05025176 0.05090097 0.0509919  0.05125817
# ...
